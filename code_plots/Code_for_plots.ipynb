# %%
import pandas as pd
import numpy as np

data = pd.read_csv("C:/Users/Aileen/Downloads/NYPD_Complaint_Data_Historic.csv")
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
data.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = ["col1", "col3", "col5"]
plotname = ['CMPLNT_FR_DT', 'CMPLNT_TO_DT', 'RPT_DT']
a = -1

for file in filename:
    a = a + 1
    f = pd.read_csv("C:/Users/Aileen/Desktop/results/" + file + "year.txt", sep = '    ',header = None)
    plt.figure(figsize=(20,10))
    plt.bar(range(len(f[0])), [i for i in f[1]])
    plt.xticks(range(len(f[0])), f[0])
    plt.xticks(rotation=70)
    plt.title("Yearly plot for " + plotname[a])
    plt.xlabel("Year")
    plt.ylabel("Frequency")
    
    # plt.plot(year1[0], year1[1])
    # plt.yscale('log')
    # plt.show()
    plt.savefig('C:/Users/Aileen/Desktop/results/' + plotname[a] + '_year.png')
    plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
filename = ["col1", "col3", "col5"]
plotname = ['CMPLNT_FR_DT', 'CMPLNT_TO_DT', 'RPT_DT']
a = -1
for file in filename:
    a = a + 1
    f = pd.read_csv("C:/Users/Aileen/Desktop/results/" + file + "month.txt", sep = '\t',header = None)
    plt.figure(figsize=(20,10))
    plt.bar(range(len(f[0])), [i for i in f[1]], align = 'center')
    plt.xticks(range(len(f[0])), f[0])
    plt.xticks(rotation=70)
    plt.title("Monthly plot for " + plotname[a])
    plt.xlabel("Month")
    plt.ylabel("Frequency")
#     plt.plot(f[0][1:], f[1][1:])
    plt.savefig('C:/Users/Aileen/Desktop/results/' + plotname[a] + '_year.png')
    plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
filename = ["col1", "col3", "col5"]
plotname = ['CMPLNT_FR_DT', 'CMPLNT_TO_DT', 'RPT_DT']
a = -1
for file in filename:
    a += 1
    f = pd.read_csv("C:/Users/Aileen/Desktop/results/" + file + "day.txt", sep = '\t',header = None)
    plt.figure(figsize=(20,10))
    plt.bar(range(len(f[0])), [i for i in f[1]], align = 'center')
    plt.xticks(range(len(f[0])), f[0])
    plt.xticks(rotation=70)
    plt.title("Daily plot for " + plotname[a])
    plt.xlabel("Day")
    plt.ylabel("Frequency")
#     plt.plot(f[0][1:], f[1][1:])
    plt.savefig('C:/Users/Aileen/Desktop/results/' + plotname[a] + '_day.png')
    plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
filename = ["col2", "col4"]
plotname = ['CMPLNT_FR_TM','CMPLNT_TO_TM']
a = 0
for file in filename:
    f = pd.read_csv("C:/Users/Aileen/Desktop/results/" + file + "hour.txt", sep = '\t',header = None)
    plt.figure(figsize=(20,10))
    plt.bar(range(len(f[0])), [i for i in f[1]], align = 'center')
    plt.xticks(range(len(f[0])), f[0])
    plt.xticks(rotation=70)
    plt.title("Hourly plot for " + plotname[a])
    plt.xlabel("Hour in a day")
    plt.ylabel("Frequency")
#     plt.plot(f[0][1:], f[1][1:])
    plt.savefig('C:/Users/Aileen/Desktop/results/' + plotname[a] + '_hour.png')
    plt.show()
    a = a + 1
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/HADEVELOPT.txt", sep = '\t',header = None)

labels = 'NULL', 'VALID'
sizes = f[1]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('Housing Dev')
# plt.savefig('HADEVELOPT.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/PARKS_NM.txt", sep = '\t',header = None)

labels = f[0]
sizes = []
for i in f[1]:
    size = i.split(',')[0]
    sizes.append(size)
plt.figure(figsize=(20,10))
plt.bar(range(len(labels)), [int(i) for i in sizes], align = 'center')
plt.xticks(range(len(labels)), labels)
plt.xticks(rotation=70)
plt.title("Plot for Parks Name" )
plt.xlabel("Parks Name")
plt.ylabel("Frequency")
#     plt.plot(f[0][1:], f[1][1:])
# plt.savefig('C:/Users/Aileen/Desktop/results/' + plotname[a] + '_hour.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/Lat_Lon.txt", sep = '\t',header = None)

labels = f[0]
sizes = f[1]
colors = ['lightgreen', 'yellow']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('Lat & Long')
plt.savefig('Lat_Lon.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/X_COORD_CD.txt", sep = '\t',header = None)

labels = f[0]
sizes = []
for i in f[1]:
    size = i.split(',')[0]
    sizes.append(size)
colors = ['violet', 'purple','yellow']
explode = (0.1, 0.1,0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('X_Coord')
plt.savefig('X_Coord.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
import numpy as np
f = pd.read_csv("C:/Users/Aileen/Desktop/results/PREM_TYP_DESC.txt", sep = '\t',header = None)
plt.figure(figsize=(20,10))
loc = []
freq = []
for i in f[0]:
    a,b = i.split(',')
    loc.append(a)
    freq.append(int(b))
indices = np.argsort(freq)[::-1]
plt.bar(range(len(loc)), [freq[i] for i in indices], color = 'lightgreen')
indice = [loc[i] for i in indices]
plt.xticks(range(len(loc)), indice)
plt.xticks(rotation=90)
plt.title("Locations Plot ")
plt.xlabel("Location")
plt.ylabel("Frequency")

plt.savefig('C:/Users/Aileen/Desktop/results/PREM_TYP_DESC.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
#ADDR_PCT_CD

labels = ['VALID', 'NULL']
sizes = [5100841, 390]

colors = ['lightblue','yellow']
explode = (0.1, 0)  # explode 1st slice
 
    
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct=make_autopct(sizes), shadow=True,startangle=140)
 
plt.axis('equal')
plt.title('ADDR_PCT_CD')
# plt.savefig('ADDR_PCT_CD.png')
plt.show()

# %%
# Borough

values = [1103514, 1011002, 1216249, 1526213, 243790, 463]
names = ['BRONX', 'QUEENS', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', 'NULL']

colors = ['lightblue','yellow', 'pink', 'violet','green', 'red']
explode = (0, 0,0,0,0.1,0.1)  # explode 1st slice
 
# Plot
plt.pie(values, explode=explode, labels=names, colors=colors,
        autopct=make_autopct(values), shadow=True,startangle=140)
 
plt.axis('equal')
plt.title('BORO_NM')
plt.savefig('BORO_NM.png')
plt.show()

# %%
# Loc of Occur

f = pd.read_csv("C:/Users/Aileen/Desktop/LOC_OF_OCCUR_DESC.txt", sep = '    ',header = None)

labels = f[0]
sizes = f[1]

colors = ['lightblue','yellow', 'pink', 'violet','green', 'red']
explode = (0, 0,0.1,0.2,0.15,0.1)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
     shadow=True,startangle=140)
 
plt.axis('equal')
plt.title('Location     ')
plt.savefig('LOC.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
