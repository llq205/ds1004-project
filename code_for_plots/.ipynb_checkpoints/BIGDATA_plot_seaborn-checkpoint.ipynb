# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/Users/twff/Downloads/NYPD.csv')
# Out:
# /Users/twff/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
data['CMPLNT_FR_DT'].unique(),len(data['CMPLNT_FR_DT'].unique())
# Out:
# (array(['12/31/2015', '04/06/2015', '06/26/2013', ..., '11/11/1998',
#         '11/05/2004', '12/02/2000'], dtype=object), 6372)

# %%
eco = pd.read_csv('/Users/twff/Downloads/big data/project/ds1004-project/NYC_Income.csv', index_col='Borough')

# %%
eco.applymap(lambda x: int(x))
# Out:
#                               2010      2011      2012      2013      2014  \
# Borough
# Bronx                        41031     42157     42652     43387     45047
# Brooklyn (Kings)             88905     94742     98584    101980    107515
# Manhattan                   180535    203477    224861    235169    250807
# Queens                       81957     85481     88524     90312     93820
# Staten Island (Richmond)     20205     20983     21560     21707     22602
# Total New York City         412633    446840    476181    492555    519791
# Total New York State        934270    991352   1053661   1072125   1119434
# Total United States       12459613  13233436  13904485  14068960  14801624
#
#                               2015
# Borough
# Bronx                        47217
# Brooklyn (Kings)            112703
# Manhattan                   257710
# Queens                       98919
# Staten Island (Richmond)     23804
# Total New York City         540353
# ...

# %%
eco
# Out:
#                             2010    2011    2012    2013    2014    2015
# Borough
# Bronx                      41031   42157   42652   43387   45047   47217
# Brooklyn (Kings)           88905   94742   98584  101980  107515  112703
# Manhattan                 180535  203477  224861  235169  250807  257710
# Queens                     81957   85481   88524   90312   93820   98919
# Staten Island (Richmond)   20205   20983   21560   21707   22602   23804

# %%
eco.columns
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015'], dtype='object')

# %%
eco = eco[:-3]

# %%
List = []
for i in eco.columns:
    List.append(str(i))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Load the example car crash dataset
#crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("deep")
sns.barplot(x='2014',y = eco.index, data=eco, label= '2011',color="g")

sns.set_color_codes("muted")
sns.barplot(x='2013',y = eco.index, data=eco,label='2012', color="g")

sns.set_color_codes("pastel")
sns.barplot(x='2012',y = eco.index, data=eco,label='2013', color="g")

sns.set_color_codes("dark")
sns.barplot(x='2011',y = eco.index, data=eco,label='2014', color="g")

# Plot the crashes where alcohol was involved


# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
#ax.set(xlim=(0, 24), ylabel="",
       #xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
dfg = data['CMPLNT_FR_DT'].groupby(data['OFNS_DESC'])

# %%
dfg.count().idxmax(), max(dfg.count()), dfg.count().idxmin()
#dfg.describe()
# Out:
# ('PETIT LARCENY', 822382, 'KIDNAPPING')

# %%
#dfg.nth(1)
data.loc[data['CMPLNT_FR_DT']=='12/31/2015']['CMPLNT_FR_DT'].groupby(data['OFNS_DESC']).count()
# df_test = pd.DataFrame()
# df_test['OFNS_DESC'] = dfg.count().index
# df_test['COUNT'] = dfg.count().values
# #df_test
# #data['CMPLNT_FR_DT']
# df_test.sort_values(['COUNT'],ascending=False)
# Out:
# OFNS_DESC
# ARSON                                2
# ASSAULT 3 & RELATED OFFENSES       100
# BURGLARY                            25
# CRIMINAL MISCHIEF & RELATED OF      47
# CRIMINAL TRESPASS                    5
# DANGEROUS DRUGS                     34
# DANGEROUS WEAPONS                   15
# FELONY ASSAULT                      43
# FORGERY                             10
# FRAUDS                               1
# FRAUDULENT ACCOSTING                 3
# GAMBLING                             1
# GRAND LARCENY                       53
# GRAND LARCENY OF MOTOR VEHICLE       7
# HARRASSMENT 2                      107
# INTOXICATED & IMPAIRED DRIVING      15
# MISCELLANEOUS PENAL LAW             18
# MURDER & NON-NEGL. MANSLAUGHTER      1
# OFF. AGNST PUB ORD SENSBLTY &       29
# OFFENSES AGAINST PUBLIC ADMINI      14
# OFFENSES AGAINST THE PERSON          3
# OFFENSES INVOLVING FRAUD             3
# OTHER OFFENSES RELATED TO THEF       4
# PETIT LARCENY                       96
# ...

# %%
def day_dist(date, col,df,n=10):
    '''
    input date and group by column
    return the distribution on that day
    '''
    dat = df.loc[df['CMPLNT_FR_DT']==date]
    dfg = dat['CMPLNT_FR_DT'].groupby(dat[col])
    maxv = max(dfg.count())
    minv = min(dfg.count())
    print('max idx %s, max value %s' % (dfg.count().idxmax(), maxv))
    print('max idx %s, max value %s' % (dfg.count().idxmin(), minv))
    
    output = pd.DataFrame()
    output[col] = dfg.count().index
    output['COUNT'] = dfg.count().values
    output = output.sort_values(['COUNT'],ascending=False).head(n)
    
    return output

# %%
df = day_dist('12/31/2015', 'OFNS_DESC',data,20)
df
# Out:
# max idx HARRASSMENT 2, max value 107
# max idx FRAUDS, max value 1
#                          OFNS_DESC  COUNT
# 14                   HARRASSMENT 2    107
# 1     ASSAULT 3 & RELATED OFFENSES    100
# 23                   PETIT LARCENY     96
# 12                   GRAND LARCENY     53
# 3   CRIMINAL MISCHIEF & RELATED OF     47
# 7                   FELONY ASSAULT     43
# 25                         ROBBERY     37
# 5                  DANGEROUS DRUGS     34
# 18   OFF. AGNST PUB ORD SENSBLTY &     29
# 2                         BURGLARY     25
# 16         MISCELLANEOUS PENAL LAW     18
# 6                DANGEROUS WEAPONS     15
# 15  INTOXICATED & IMPAIRED DRIVING     15
# 19  OFFENSES AGAINST PUBLIC ADMINI     14
# 28        VEHICLE AND TRAFFIC LAWS     10
# 8                          FORGERY     10
# 26                      SEX CRIMES      8
# 13  GRAND LARCENY OF MOTOR VEHICLE      7
# 4                CRIMINAL TRESPASS      5
# 22  OTHER OFFENSES RELATED TO THEF      4

# %%
df['COUNT'] = df['COUNT'].map(lambda x: int(x))

# %%
'12/31/2015'.split('/')
# Out:
# ['12', '31', '2015']

# %%
from datetime import datetime

datetime_object = datetime.strptime('12/31/2015', '%m/%d/%Y')
datetime_object
# Out:
# datetime.datetime(2015, 12, 31, 0, 0)

# %%
def date_rng(start, end, df):
    '''
    input start date and end date
    return corresponding dataframe
    '''
    dlist = []
    date_start = datetime.strptime(start, '%m/%d/%Y')
    #print(date_start)
    date_end = datetime.strptime(end, '%m/%d/%Y')
    #print(date_end)
    datelist = pd.date_range(date_start,date_end).tolist()
    #print(datelist)
    for d in datelist:
        dlist.append(d.strftime('%m/%d/%Y'))
    dat = df.loc[df['CMPLNT_FR_DT'].isin(dlist)]
    return dat

# %%
year = [2010,2011,2012,2013,2014,2015]

# %%
Bor_year = pd.DataFrame()
Bor_year['Bor_Nm'] = ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
for i in year:
    j = i + 1
    sy = '01/01/%s' %i
    ey = '01/01/%s' %j
    dy = date_rng(sy,ey,data)
    Bor_year[i] = dy['CMPLNT_NUM'].groupby(data['BORO_NM']).count().values

# %%
Bor_year.set_index('Bor_Nm', inplace =True)
Bor_year.T.plot()
plt.legend(loc='best')

# %%
eco1.astype('int').plot()
plt.legend(loc='best')

# %%
#f, axes = plt.subplots(2, 1, figsize=(7, 7), sharex=True)

plt.subplot(2, 1, 1)
Bor_year.T.plot()
plt.legend(loc='best')

plt.subplot(2, 1, 2)
eco1.astype('int').plot()
plt.legend(loc='best')

plt.show()

# %%
df = df.astype(int)

# %%
len(df.unique())
# Out:
# 415

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = ["col1", "col3", "col5"]
plotname = ['CMPLNT_FR_DT', 'CMPLNT_TO_DT', 'RPT_DT']
a = -1

f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

for file in filename:
    a = a + 1
    df = pd.read_csv("/Users/twff/Downloads/big data/project/ds1004-project/results/" + file + "year_new.txt", sep = '    ',header = None)
    #plt.figure(figsize=(10,6))
    plt.bar(range(len(df[0])), [i for i in df[1]],)
    plt.xticks(range(len(df[0])), df[0])
    plt.xticks(rotation=70)
    plt.title("Yearly plot for " + plotname[a])
    plt.xlabel("Year")
    plt.ylabel("Frequency")
    
    # plt.plot(year1[0], year1[1])
    # plt.yscale('log')
    # plt.show()
plt.setp(axes, yticks=[])
plt.tight_layout()
plt.savefig('/Users/twff/Downloads/big data/project/ds1004-project/images' + plotname[a] + '_year_new.png')
# Out:
# /Users/twff/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/Lat_Lon.txt", sep = '\t',header = None)

labels = f[0]
sizes = f[1]
colors = ['lightgreen', 'yellow']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('Lat & Long')
plt.savefig('Lat_Lon.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
f = pd.read_csv("C:/Users/Aileen/Desktop/results/X_COORD_CD.txt", sep = '\t',header = None)

labels = f[0]
sizes = []
for i in f[1]:
    size = i.split(',')[0]
    sizes.append(size)
colors = ['violet', 'purple','yellow']
explode = (0.1, 0.1,0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.title('X_Coord')
plt.savefig('X_Coord.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
import numpy as np
f = pd.read_csv("C:/Users/Aileen/Desktop/results/PREM_TYP_DESC.txt", sep = '\t',header = None)
plt.figure(figsize=(20,10))
loc = []
freq = []
for i in f[0]:
    a,b = i.split(',')
    loc.append(a)
    freq.append(int(b))
indices = np.argsort(freq)[::-1]
plt.bar(range(len(loc)), [freq[i] for i in indices], color = 'lightgreen')
indice = [loc[i] for i in indices]
plt.xticks(range(len(loc)), indice)
plt.xticks(rotation=90)
plt.title("Locations Plot ")
plt.xlabel("Location")
plt.ylabel("Frequency")

plt.savefig('C:/Users/Aileen/Desktop/results/PREM_TYP_DESC.png')
plt.show()
# Out:
# C:\Users\Aileen\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
#ADDR_PCT_CD

labels = ['VALID', 'NULL']
sizes = [5100841, 390]

colors = ['lightblue','yellow']
explode = (0.1, 0)  # explode 1st slice
 
    
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct


# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct=make_autopct(sizes), shadow=True,startangle=140)
 
plt.axis('equal')
plt.title('ADDR_PCT_CD')
# plt.savefig('ADDR_PCT_CD.png')
plt.show()

# %%
# Borough

values = [1103514, 1011002, 1216249, 1526213, 243790, 463]
names = ['BRONX', 'QUEENS', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', 'NULL']

colors = ['lightblue','yellow', 'pink', 'violet','green', 'red']
explode = (0, 0,0,0,0.1,0.1)  # explode 1st slice
 
# Plot
plt.pie(values, explode=explode, labels=names, colors=colors,
        autopct=make_autopct(values), shadow=True,startangle=140)
 
plt.axis('equal')
plt.title('BORO_NM')
plt.savefig('BORO_NM.png')
plt.show()

# %%
values = [1103514, 1011002, 1216249, 1526213, 243790, 463]
names = ['BRONX', 'QUEENS', 'MANHATTAN', 'BROOKLYN', 'STATEN ISLAND', 'NULL']
bor = pd.DataFrame(data=names, columns = ['name'])
bor['count'] = values

# %%
bor
# Out:
#             name    count
# 0          BRONX  1103514
# 1         QUEENS  1011002
# 2      MANHATTAN  1216249
# 3       BROOKLYN  1526213
# 4  STATEN ISLAND   243790
# 5           NULL      463

# %%
#colors = ['lightblue','yellow', 'pink', 'violet','green', 'red']
#explode = (0, 0,0,0,0.1,0.1)  # explode 1st slice
sns.set_style("whitegrid")
# Plot
sns.factorplot(x='name',y='count',data=bor)
plt.savefig('/Users/twff/Downloads/big data/project/ds1004-project/images/Bor1.jpg')

# %%
sns.set_color_codes("pastel")
sns.barplot(x='name',y='count',data=bor,palette="BuGn_r")
plt.title('Count by Borough')
plt.savefig('/Users/twff/Downloads/big data/project/ds1004-project/images/Bor2.jpg')

# %%
sns.set(rc={"figure.figsize": (8, 4)})
sns.distplot(bor['count'], kde=False, color="b")

# %%
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(values, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(values, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(values, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a historgram and kernel density estimate
sns.distplot(values, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
values = [5013311, 87913, 7]
names = ['COMPLETED', 'ATTEMPTED', 'NULL']
bor = pd.DataFrame(data=names, columns = ['name'])
bor['count'] = values
sns.set_color_codes("pastel")
sns.barplot(x='name',y='count',data=bor,palette="BuGn_r")
plt.title('Count by Progress')
plt.savefig('/Users/twff/Downloads/big data/project/ds1004-project/images/Progress.jpg')

# %%
values = [1567423, 2918574, 615234]
names = ['FELONY', 'MISDEMEANOR', 'VIOLATION']
bor = pd.DataFrame(data=names, columns = ['name'])
bor['count'] = values
sns.set_color_codes("pastel")
sns.barplot(x='name',y='count',data=bor,palette="BuGn_r")
plt.title('Count by Crime Character')
plt.savefig('/Users/twff/Downloads/big data/project/ds1004-project/images/CrimeType.jpg')
